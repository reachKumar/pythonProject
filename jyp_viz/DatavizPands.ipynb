# %%
from matplotlib import pyplot as plt
import pandas as pt

# %%
data = {
    'Year':[ 2020,2022,2023],
    'No of Att':[50,44,65],
    'Company Cost':[500,700,900]
}
df= pt.DataFrame(data)

# %%
df
# Out:
#    Year  No of Att  Company Cost
# 0  2020         50           500
# 1  2022         44           700
# 2  2023         65           900

# %%
#To query only single column

# %%
df['Year']
# Out:
# 0    2020
# 1    2022
# 2    2023
# Name: Year, dtype: int64

# %%
plt.plot(df['Year'],df['No of Att'])
plt.show()
